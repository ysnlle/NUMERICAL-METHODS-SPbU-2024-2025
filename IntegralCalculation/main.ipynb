# %%
import pandas as pd
import numpy as np
from errors import *
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('darkgrid')

# %%
errors_df = abs_error()
sns.lineplot(data=errors_df)
errors_df
# Out:
#      Left Rectangles  Right Rectangles  Medium Rectangles  Trapezoid  \
# 10          0.619854          0.634966           0.621445   0.627410
# 20          0.308994          0.316551           0.311352   0.312772
# 40          0.154286          0.158064           0.155828   0.156175
# 80          0.077092          0.078981           0.077951   0.078037
# 100         0.061666          0.063177           0.062367   0.062421
# 150         0.041103          0.042111           0.041583   0.041607
# 200         0.030825          0.031581           0.031189   0.031203
#
#       Simpson     Gauss  Newton-Cotes
# 10   0.644453  0.012480      0.032297
# 20   0.318987  0.006255      0.016524
# 40   0.158678  0.003131      0.008324
# 80   0.079135  0.001566      0.004175
# 100  0.063276  0.001253      0.003342
# 150  0.042155  0.000836      0.002230
# 200  0.031605  0.000627      0.001673
